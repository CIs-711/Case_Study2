# %%
pip install cssselect

# %%
import numpy as np 
import pandas as pd
import requests 
from bs4 import BeautifulSoup
import csv
from lxml import html
import requests
import pandas as pd
import numpy as np
import re

# %% [markdown]
# **Teams' pages scraping**
#
# In this section, we are scraping the pages for each team in Primier League. To do so , we will first access the page containing all clubs. Then , we will loop through all teams and save their links in a list so we can use them latter. In the clubs page, each team is represented by a link that takes you to the team page containing its stats and overview

# %%
#Take site and structure html

page = requests.get('https://www.premierleague.com/clubs')
tree = html.fromstring(page.content)

# %%
# extract link locations related to the teams contained in the page
linkLocation = tree.cssselect('.indexItem')

# %%
#Create an empty list for us to send each team's link to
teamLinks = []

# There are 20 teams, we will loop through them 
for i in range(0,20):
    
    # A variable that contains the ith team's link location
    temp = linkLocation[i].attrib['href']
    
    # To access the page of each team using the code i.e not manually, we will add the team's link to the website domain 
    temp = "http://www.premierleague.com/" + temp
    print(temp)
    # When opening the team's page it will be the overview page, we will change it to squad since we are interested in players
    temp = temp.replace("overview", "squad")
   
    #Add the finished link to our teamLinks list
    teamLinks.append(temp)
# Out:
# http://www.premierleague.com//clubs/1/Arsenal/overview
# http://www.premierleague.com//clubs/2/Aston-Villa/overview
# http://www.premierleague.com//clubs/131/Brighton-and-Hove-Albion/overview
# http://www.premierleague.com//clubs/43/Burnley/overview
# http://www.premierleague.com//clubs/4/Chelsea/overview
# http://www.premierleague.com//clubs/6/Crystal-Palace/overview
# http://www.premierleague.com//clubs/7/Everton/overview
# http://www.premierleague.com//clubs/34/Fulham/overview
# http://www.premierleague.com//clubs/9/Leeds-United/overview
# http://www.premierleague.com//clubs/26/Leicester-City/overview
# http://www.premierleague.com//clubs/10/Liverpool/overview
# http://www.premierleague.com//clubs/11/Manchester-City/overview
# http://www.premierleague.com//clubs/12/Manchester-United/overview
# http://www.premierleague.com//clubs/23/Newcastle-United/overview
# http://www.premierleague.com//clubs/18/Sheffield-United/overview
# http://www.premierleague.com//clubs/20/Southampton/overview
# http://www.premierleague.com//clubs/21/Tottenham-Hotspur/overview
# http://www.premierleague.com//clubs/36/West-Bromwich-Albion/overview
# http://www.premierleague.com//clubs/25/West-Ham-United/overview
# http://www.premierleague.com//clubs/38/Wolverhampton-Wanderers/overview

# %% [markdown]
# **Players' pages scraping**
#
# In this section, we will use the links we have got for each team and we will make a list of similar links for all playeras in that team. This will help us scrape the information of each player later

# %%
#Create empty lists for player links
#First list is used for links in the overview page of each player while the second is used for the stats page
#Each page contains information we will need for each player
playerLink1 = []
playerLink2 = []

#looping through teams using their links
for i in range(len(teamLinks)):
    
    #accessing each team page 
    squadPage = requests.get(teamLinks[i])
    squadTree = html.fromstring(squadPage.content)
    
    #Extracting players' links, they are under class 'playerOverviewCard'
    playerLocation = squadTree.cssselect('.playerOverviewCard')

    #loop through players links in order to add them to the website domain. This eliminates the need for accessing each players page manually
    for i in range(len(playerLocation)):
        
        # add the link to the website domain 
        playerLink1.append("http://www.premierleague.com/" + playerLocation[i].attrib['href'])
       
        #...For the second link, change the page from player overview to stats
        #playerLink2.append(playerLink1[i])

# %%
for i in range(len(playerLink1)):
    temp=playerLink1[i].replace("overview", "stats")
    playerLink2.append(playerLink1[i].replace("overview", "stats"))

# %%
playerLink1[50]
# Out:
# 'http://www.premierleague.com//players/51423/John-McGinn/overview'

# %%
playerLink2[50]
# Out:
# 'http://www.premierleague.com//players/51423/John-McGinn/stats'

# %%
#Create lists for each variable
Name = []
Team = []
Age = []
Apps = []
HeightCM = []
WeightKG = []
Goals= []
Assists=[]
Passes=[]
Wins=[]
Losses=[]
Yellowcards=[]
Redcards=[]
Fouls=[]
Position=[]

# %%
for i in range(len(playerLink1)):

    #...download and process the two pages collected earlier...
    playerPage1 = requests.get(playerLink1[i])
    playerTree1 = html.fromstring(playerPage1.content)
    playerPage2 = requests.get(playerLink2[i])
    playerTree2 = html.fromstring(playerPage2.content)

    #...find the relevant datapoint for each player, starting with name...
    tempName = str(playerTree1.cssselect('div.name')[0].text_content())
    #print(tempName)
    
    #...and team, but if there isn't a team, return "BLANK"...
    try:
        tempTeam = str(playerTree1.cssselect('.table:nth-child(1) .long')[0].text_content())
    except IndexError:
        tempTeam = str("BLANK")
    #print(tempTeam)
    
    #...and age, but if this isn't there, leave a blank 'no number' number...
    try:  
        tempAge = playerTree1.cssselect('.pdcol2 li:nth-child(1) .info--light')[0].text_content()
        res= tempAge[tempAge.find("(")+1:tempAge.find(")")]
        #res = re.findall(r"\(\s*\+?(-?\d+)\s*\)", tempAge)
    except IndexError:
        tempAge = float('NaN')
    #print(res) 

    #...and appearances. This is a bit of a mess on the page, so tidy it first...
    try:
        tempApps = playerTree2.cssselect('.statappearances')[0].text_content()
        tempApps = int(re.search(r'\d+', tempApps).group())
    except IndexError:
        tempApps = float('NaN')
        

    #...and height. Needs tidying again...
    try:
        tempHeight = playerTree1.cssselect('.pdcol3 li:nth-child(1) .info')[0].text_content()
        tempHeight = int(re.search(r'\d+', tempHeight).group())
    except IndexError:
        tempHeight = float('NaN')

    #...and weight. Same with tidying and returning blanks if it isn't there
    try:
        tempWeight = playerTree1.cssselect('.pdcol3 li+ li .info')[0].text_content()
        tempWeight = int(re.search(r'\d+', tempWeight).group())
    except IndexError:
        tempWeight = float('NaN')
    
    try:
        tempgoals =  playerTree2.cssselect('.statgoals')[0].text_content()
        tempgoals = int(re.search(r'\d+', tempgoals).group())
    except IndexError:
        tempgoals = float('NaN')
    #print(tempgoals)
    
    try:
        tempassists =  playerTree2.cssselect('.statgoal_assist')[0].text_content()
        tempassists = int(re.search(r'\d+', tempassists).group())
    except IndexError:
        tempassists = float('NaN')
    #print(tempassists)
    
    try:
        tempapasses =  playerTree2.cssselect('.stattotal_pass')[0].text_content()
        res2=tempapasses.replace(",", "")
        tempapasses = int(re.search(r'\d+', res2).group())
        
    except IndexError:
        tempapasses = float('NaN')
    #print(tempapasses)
    
    
    try:
        tempwins = playerTree2.cssselect('.statwins')[0].text_content()
        tempwins = int(re.search(r'\d+', tempwins).group())
    except IndexError:
        tempwins = float('NaN')
    
    try:
        templosses = playerTree2.cssselect('.statlosses')[0].text_content()
        templosses = int(re.search(r'\d+', templosses).group())
    except IndexError:
        templosses = float('NaN')
        
    try:
        tempYellowcards = playerTree2.cssselect('.statyellow_card')[0].text_content()
        tempYellowcards = int(re.search(r'\d+', tempYellowcards).group())
    except IndexError:
        tempYellowcards = float('NaN')
        
    try:
        tempRedcards = playerTree2.cssselect('.statred_card')[0].text_content()
        tempRedcards = int(re.search(r'\d+', tempRedcards).group())
    except IndexError:
        tempRedcards = float('NaN')
        
    try:
        tempFouls = playerTree2.cssselect('.statfouls')[0].text_content()
        tempFouls = int(re.search(r'\d+', tempFouls).group())
    except IndexError:
        tempFouls = float('NaN')     
        
    try:
        tempposition = str(playerTree1.cssselect('.playerOverviewAside .info')[1].text_content())
    except IndexError:
        tempposition = str("BLANK")
    #print(tempposition)
    
    #Now that we have a player's full details - add them all to the lists
    
    Name.append(tempName)
    Team.append(tempTeam)
    Age.append(res)
    Apps.append(tempApps)
    HeightCM.append(tempHeight)
    WeightKG.append(tempWeight)
    Goals.append(tempgoals)
    Assists.append(tempassists)
    Passes.append(tempapasses)
    Wins.append(tempwins)
    Losses.append(templosses)
    Yellowcards.append(tempYellowcards)
    Redcards.append(tempRedcards)
    Fouls.append(tempFouls)
    Position.append(tempposition)

# %%
#Create data frame from lists
df = pd.DataFrame(
    {'Name':Name,
     'Team':Team,
     'Positon':Position,
     'Age':Age,
     'Apps':Apps,
     'HeightCM':HeightCM,
     'WeightKG':WeightKG,
    'Goals':Goals,
    'Assists':Assists,
    'Passes':Passes,
     'Wins':Wins,
      'Losses':Losses,
   'Yellowcards':Yellowcards,
    'Redcards':Redcards,
    'Fouls':Fouls})

#Show me the top 3 rows:

df.head(50)
# Out:
#                          Name              Team     Positon Age  Apps  \
# 0                  Bernd Leno           Arsenal  Goalkeeper  29    93
# 1      RÃºnar Alex RÃºnarsson           Arsenal  Goalkeeper  26     1
# 2                   Karl Hein           Arsenal  Goalkeeper  19     0
# 3                    Mat Ryan  Arsenal  (Loan)   Goalkeeper  29   124
# 4              Arthur Okonkwo           Arsenal  Goalkeeper  19     0
# 5               James Hillson           Arsenal  Goalkeeper  20     0
# 6           HÃ©ctor BellerÃ­n           Arsenal    Defender  26   182
# 7              Kieran Tierney           Arsenal    Defender  23    38
# 8                 Rob Holding           Arsenal    Defender  25    65
# 9              Calum Chambers           Arsenal    Defender  26   145
# 10                 David Luiz           Arsenal    Defender  34   213
# 11         Gabriel MagalhÃ£es           Arsenal    Defender  23    19
# 12             CÃ©dric Soares           Arsenal    Defender  29   135
# 13                Pablo MarÃ­           Arsenal    Defender  27    11
# 14        Joel Lopez Salguero           Arsenal    Defender  19     0
# 15             Mohamed Elneny           Arsenal  Midfielder  28    66
# 16           Emile Smith Rowe           Arsenal  Midfielder  20    18
# 17               Granit Xhaka           Arsenal  Midfielder  28   159
# 20     178.0      68.0      1        0     391     4       4            0
# 21       NaN       NaN      0        0       0     0       0            0
# 22       NaN       NaN      0        0       0     0       0            0
# 23     179.0      70.0      0        5    2449    20      17            4
# 24     175.0      73.0     50       18    2496    55      40           14
# 25     187.0      80.0     64       14    2393    51      36            5
# 26       NaN       NaN     10        7    1206    22      19            5
# 27     175.0      71.0      1        0     303    10       6            1
# 28     175.0      72.0      5        1     258    15      16            0
# 29     180.0      75.0      4        1     241     8       6            1
# 30     175.0      77.0     37       38    8852   147      56           21
# 31     178.0      66.0      0        0       0     0       0            0
# 32     188.0      85.0      0        0    3290    34      55            5
# 33     183.0      80.0      0        0      32     0       2            0
# 34     195.0      88.0      0        0    1368    22      19            2
# 35       NaN       NaN      0        0       0     0       0            0
# 36       NaN       NaN      0        0       0     0       0            0
# 37     176.0      64.0      0        5    5500    48      63           22
# 38     183.0      77.0      3        2    1897    20      25            6
# 39     183.0      70.0      2        7    3642    37      41           14
# 40     193.0      83.0      1        0     647     3      12            1
# 41     183.0      75.0      6       13    7010    51      95           14
# 42     191.0      77.0      2        0     940     5      11            4
# 43     196.0      77.0      4        4    3405    26      40           12
# 44     185.0       NaN      0        2     948    13      11            6
# 45       NaN       NaN      0        0       0     0       0            0
# 46       NaN       NaN      0        0       0     0       0            0
# 47       NaN       NaN      0        0       0     0       0            0
# 48       NaN       NaN      0        0       0     0       0            0
# 49     175.0      66.0      3        4    2467    21      32           16
#
#     Redcards  Fouls
# 0          1      2
# 1          0      0
# 2          0      0
# 3          0      2
# 4          0      0
# 5          0      0
# 6          0    143
# 7          0     19
# 8          0     49
# 9          1    141
# 10         4    227
# 11         1     20
# 12         0     87
# 13         0     10
# 14         0      0
# 15         1     33
# 16         0      5
# 17         3    233
# 18         0     45
# 19         0     14
# 20         0      1
# 21         0      0
# 22         0      0
# 23         0     41
# 24         0    158
# 25         1     41
# 26         1     23
# 27         0     10
# 28         1     28
# 29         0     18
# 30         1    135
# 31         0      0
# 32         0      2
# 33         0      0
# 34         0      2
# 35         0      0
# 36         0      0
# 37         0    122
# 38         0     34
# 39         0     62
# 40         0      5
# 41         1    158
# 42         0     26
# 43         1     47
# 44         1     32
# 45         0      0
# 46         0      0
# 47         0      0
# 48         0      0
# 49         1    104

# %%
df.shape
# Out:
# (638, 15)

# %%
df.dtypes
# Out:
# Name                   object
# Team                   object
# Positon                object
# Age                     int64
# Apps                    int64
# HeightCM              float64
# WeightKG              float64
# Goals                   int64
# Assists                 int64
# Passes                  int64
# Wins                    int64
# Losses                  int64
# Yellowcards             int64
# Redcards                int64
# Fouls                   int64
# Wins_ratio            float64
# Yellowcardsd_ratio    float64
# Fouls_ratio           float64
# Passes_ratio          float64
# dtype: object

# %%
df['Age']=pd.to_numeric(df['Age'])

# %%
df['Age'].dtype
# Out:
# dtype('int64')

# %%
df=df[df['Apps']!=0]

# %%
df.shape
# Out:
# (508, 19)

# %%
# any anlysis of weight and height needs some preproccesing for nul values
df.isnull().sum()
# Out:
# Name                        0
# Team                        0
# Positon                     0
# Age                         0
# Apps                        0
# HeightCM                   44
# WeightKG                   56
# Goals                       0
# Assists                     0
# Passes                      0
# Wins                        0
# Losses                      0
# Yellowcards                 0
# Redcards                    0
# Fouls                       0
# Wins_ratio                  0
# Yellowcardsd_ratio          0
# Fouls_ratio                 0
# Passes_ratio                0
# Ycards_ratio_dicretized     0
# Fouls_ratio_dicretized      0
# dtype: int64

# %%
#creating new columns
try:
    df['Wins_ratio'] = df['Wins'] / df['Apps']
except ZeroDivisionError:
    df['Wins_ratio'] = 0
    
    
try:
    df['Yellowcardsd_ratio'] = df['Yellowcards'] / df['Apps']
except ZeroDivisionError:
    df['Yellowcardsd_ratio'] = 0
    
    
try:
    df['Fouls_ratio'] = df['Fouls'] / df['Apps']
except ZeroDivisionError:
    df['Fouls_ratio'] = 0
    
try:
    df['Passes_ratio'] = df['Passes'] / df['Apps']
except ZeroDivisionError:
    df['Passes_ratio'] = 0

# %%
df.head(50)
# Out:
#                          Name                  Team     Positon  Age  Apps  \
# 0                  Bernd Leno               Arsenal  Goalkeeper   29    93
# 1      RÃºnar Alex RÃºnarsson               Arsenal  Goalkeeper   26     1
# 3                    Mat Ryan      Arsenal  (Loan)   Goalkeeper   29   124
# 6           HÃ©ctor BellerÃ­n               Arsenal    Defender   26   182
# 7              Kieran Tierney               Arsenal    Defender   23    38
# 8                 Rob Holding               Arsenal    Defender   25    65
# 9              Calum Chambers               Arsenal    Defender   26   145
# 10                 David Luiz               Arsenal    Defender   34   213
# 11         Gabriel MagalhÃ£es               Arsenal    Defender   23    19
# 12             CÃ©dric Soares               Arsenal    Defender   29   135
# 13                Pablo MarÃ­               Arsenal    Defender   27    11
# 15             Mohamed Elneny               Arsenal  Midfielder   28    66
# 16           Emile Smith Rowe               Arsenal  Midfielder   20    18
# 17               Granit Xhaka               Arsenal  Midfielder   28   159
# 18                Bukayo Saka               Arsenal  Midfielder   19    55
# 19              Thomas Partey               Arsenal  Midfielder   27    20
# 20           Martin Ãdegaard      Arsenal  (Loan)   Midfielder   22    11
# 23              Dani Ceballos      Arsenal  (Loan)   Midfielder   24    48
# 24        Alexandre Lacazette               Arsenal     Forward   29   125
# 25  Pierre-Emerick Aubameyang               Arsenal     Forward   31   111
# 26             Nicolas PÃ©pÃ©               Arsenal     Forward   31    57
# 27               Reiss Nelson               Arsenal     Forward   21    22
# 28              Eddie Nketiah               Arsenal     Forward   21    38
# 29         Gabriel Martinelli               Arsenal     Forward   19    25
# 30                    Willian               Arsenal     Forward   32   258
# 32                 Tom Heaton           Aston Villa  Goalkeeper   35   116
# 33                  Jed Steer           Aston Villa  Goalkeeper   28     2
# 34         Emiliano MartÃ­nez           Aston Villa  Goalkeeper   28    48
# 37                Neil Taylor           Aston Villa    Defender   32   146
# 38           Ezri Konsa Ngoyo           Aston Villa    Defender   23    56
# 39               Matt Targett           Aston Villa    Defender   25   104
# 53         0     34    0.350000            0.175000     0.850000     25.075000
# 54         1     74    0.309091            0.036364     1.345455     11.854545
# 55         0     32    0.263158            0.087719     0.561404     15.491228
# 56         0     14    0.200000            0.000000     0.466667      6.066667
# 57         0    167    0.437500            0.080357     0.745536     37.236607
# 67         0      6    0.222222            0.333333     0.666667     15.333333
# 68         0     10    0.444444            0.000000     0.555556      9.277778
# 72         0     43    0.272727            0.136364     1.954545     16.727273
# 73         0     40    0.424242            0.060606     1.212121     21.939394
# 74         0     30    0.341463            0.000000     0.731707     18.048780

# %%
# descritizing of some columns
df['Ycards_ratio_dicretized']=pd.qcut(df['Yellowcardsd_ratio'],3, labels=['Low','Medium','High'])
df['Fouls_ratio_dicretized']=pd.qcut(df['Fouls_ratio'],3, labels=['Low','Medium','High'])
# Out:
# <ipython-input-241-c2e34c41abb0>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Ycards_ratio_dicretized']=pd.qcut(df['Yellowcardsd_ratio'],3, labels=['Low','Medium','High'])
# <ipython-input-241-c2e34c41abb0>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Fouls_ratio_dicretized']=pd.qcut(df['Fouls_ratio'],3, labels=['Low','Medium','High'])

# %%
df.head(20)
# Out:
#                          Name              Team     Positon  Age  Apps  \
# 0                  Bernd Leno           Arsenal  Goalkeeper   29    93
# 1      RÃºnar Alex RÃºnarsson           Arsenal  Goalkeeper   26     1
# 3                    Mat Ryan  Arsenal  (Loan)   Goalkeeper   29   124
# 6           HÃ©ctor BellerÃ­n           Arsenal    Defender   26   182
# 7              Kieran Tierney           Arsenal    Defender   23    38
# 8                 Rob Holding           Arsenal    Defender   25    65
# 9              Calum Chambers           Arsenal    Defender   26   145
# 10                 David Luiz           Arsenal    Defender   34   213
# 11         Gabriel MagalhÃ£es           Arsenal    Defender   23    19
# 12             CÃ©dric Soares           Arsenal    Defender   29   135
# 13                Pablo MarÃ­           Arsenal    Defender   27    11
# 15             Mohamed Elneny           Arsenal  Midfielder   28    66
# 16           Emile Smith Rowe           Arsenal  Midfielder   20    18
# 17               Granit Xhaka           Arsenal  Midfielder   28   159
# 18                Bukayo Saka           Arsenal  Midfielder   19    55
# 19              Thomas Partey           Arsenal  Midfielder   27    20
# 20           Martin Ãdegaard  Arsenal  (Loan)   Midfielder   22    11
# 23              Dani Ceballos  Arsenal  (Loan)   Midfielder   24    48
# 24        Alexandre Lacazette           Arsenal     Forward   29   125
# 25  Pierre-Emerick Aubameyang           Arsenal     Forward   31   111
#
#     HeightCM  WeightKG  Goals  Assists  Passes  ...  Losses  Yellowcards  \
# 0      190.0      83.0      0        0    2616  ...      28            2
# 1      186.0      76.0      0        0       9  ...       1            0
# 3      184.0      82.0      0        0    3596  ...      55            3
# 6      178.0      74.0      8       20    8136  ...      47           30
# 7      178.0      70.0      2        3    1528  ...      15            6
# 8      189.0      75.0      0        1    3600  ...      20           10
# 9      182.0      66.0      6        3    6207  ...      59           28
# 10     189.0      84.0     14        7   11161  ...      45           41
# 11     190.0      78.0      2        0    1298  ...       9            2
# 12     172.0      67.0      2       12    4869  ...      52           19
# 13     193.0      87.0      0        0     685  ...       3            2
# 15     180.0      70.0      1        3    3288  ...      16            9
# 16     182.0      79.0      0        4     608  ...       5            0
# 17     185.0      82.0      9       15   11648  ...      43           42
# 18     178.0      65.0      6        7    1564  ...      18            7
# 19     185.0      77.0      0        2     948  ...       8            4
# 20     178.0      68.0      1        0     391  ...       4            0
# 23     179.0      70.0      0        5    2449  ...      17            4
# 24     175.0      73.0     50       18    2496  ...      40           14
# 25     187.0      80.0     64       14    2393  ...      36            5
#
#     Redcards  Fouls  Wins_ratio  Yellowcardsd_ratio  Fouls_ratio  \
# 0          1      2    0.419355            0.021505     0.021505
# 1          0      0    0.000000            0.000000     0.000000
# 3          0      2    0.233871            0.024194     0.016129
# 6          0    143    0.538462            0.164835     0.785714
# 7          0     19    0.394737            0.157895     0.500000
# 8          0     49    0.507692            0.153846     0.753846
# 9          1    141    0.337931            0.193103     0.972414
# 10         4    227    0.563380            0.192488     1.065728
# 11         1     20    0.368421            0.105263     1.052632
# 12         0     87    0.333333            0.140741     0.644444
# 13         0     10    0.545455            0.181818     0.909091
# 15         1     33    0.606061            0.136364     0.500000
# 16         0      5    0.444444            0.000000     0.277778
# 17         3    233    0.509434            0.264151     1.465409
# 18         0     45    0.381818            0.127273     0.818182
# 19         0     14    0.350000            0.200000     0.700000
# 20         0      1    0.363636            0.000000     0.090909
# 23         0     41    0.416667            0.083333     0.854167
# 24         0    158    0.440000            0.112000     1.264000
# 25         1     41    0.459459            0.045045     0.369369
#
#     Passes_ratio  Ycards_ratio_dicretized Fouls_ratio_dicretized
# 0      28.129032                      Low                    Low
# 1       9.000000                      Low                    Low
# 3      29.000000                      Low                    Low
# 6      44.703297                     High                 Medium
# 7      40.210526                     High                    Low
# 8      55.384615                     High                 Medium
# 9      42.806897                     High                   High
# 10     52.399061                     High                   High
# 11     68.315789                   Medium                   High
# 12     36.066667                     High                 Medium
# 13     62.272727                     High                   High
# 15     49.818182                     High                    Low
# 16     33.777778                      Low                    Low
# 17     73.257862                     High                   High
# 18     28.436364                   Medium                 Medium
# 19     47.400000                     High                 Medium
# 20     35.545455                      Low                    Low
# 23     51.020833                   Medium                 Medium
# 24     19.968000                   Medium                   High
# 25     21.558559                      Low                    Low
#
# [20 rows x 21 columns]

# %% [markdown]
# **Analysis of different groups**

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import binom
from scipy.stats import chi2_contingency
from scipy.stats import chi2
from scipy import stats

# %%
df.groupby('Positon')['Fouls'].sum()
# Out:
# Positon
# Defender      11994
# Forward        8729
# Goalkeeper       60
# Midfielder    14602
# Name: Fouls, dtype: int64

# %%
df.groupby('Positon').count()
# Out:
#             Name  Team  Age  Apps  HeightCM  WeightKG  Goals  Assists  Passes  \
# Positon
# Defender     209   209  209   209       168       158    209      209     209
# Forward      125   125  125   125       101        98    125      125     125
# Goalkeeper    79    79   79    79        64        61     79       79      79
# Midfielder   225   225  225   225       170       163    225      225     225
#
#             Wins  Losses  Yellowcards  Redcards  Fouls  Wins_ratio
# Positon
# Defender     209     209          209       209    209         171
# Forward      125     125          125       125    125         109
# Goalkeeper    79      79           79        79     79          52
# Midfielder   225     225          225       225    225         176

# %%
df.groupby('Positon')['Fouls'].describe()
# Out:
#             count       mean        std  min   25%   50%    75%    max
# Positon
# Defender    209.0  57.387560  68.856861  0.0   8.0  33.0   82.0  333.0
# Forward     125.0  69.832000  85.972214  0.0  10.0  34.0  107.0  386.0
# Goalkeeper   79.0   0.759494   1.495422  0.0   0.0   0.0    1.0    7.0
# Midfielder  225.0  64.897778  86.534589  0.0   0.0  33.0   88.0  456.0

# %%
sns.catplot(x="Positon", y="Age", kind="box", data=df)
#plot the distribution of each

# %%
sns.catplot(x="Team", y="Age", kind="box", data=df)

# %%
sns.catplot(x="Positon", y="HeightCM", kind="box", data=df)
#plot the distribution of each

# %% [markdown]
# **Analysis of Fouls**

# %%
sns.catplot(x="Positon", y="Fouls_ratio", kind="box", data=df)

# %%
df_highApps=df[df['Apps']>50]

# %%
df_highApps.shape
# Out:
# (284, 21)

# %%
sns.boxplot(y=df["Fouls_ratio"])
# Out:
# <AxesSubplot:ylabel='Fouls_ratio'>

# %%
sns.relplot(x="Apps", y="Fouls", data=df)

# %%
sns.relplot(x="Apps", y="Fouls",hue='Positon' ,data=df)

# %% [markdown]
# There seems to be a positive  correlatoin between the number of apps and the number of fouls commited by players in each position. The only exception for this is relationof apps of goal keepers and their commited fouls. It is obvious that the number of fouls committed by goal keeper is low regardless of the number of games they have played. This could be attributed to the fact that goal keepers usually have less contact with other players.
#
# In order to check if there is a statistical difference of the fouls according to the different position of players:
#
# First a new column that represent the ratio of fouls committed by each player per game.
#
# Second the resulting column is continous, so this column has been dicreted by three quantiles (Low, Medium, High)
#
# Third a contingency table that shows the count of each category of the fouls ratio per game according to the different positions is obtained, In this table the columns represent the three categories of fouls ratio per game (Low, Medium,High), While rows represent the categories of the different positions
#
# Finally, a Chi-squre test is conducted to investigate the dependence of the (ratio of fouls commited ) on the position of players

# %%
# Make a separate list for each airline
x1 = list(df[df['Positon'] == 'Goalkeeper']['Fouls'])
x2 = list(df[df['Positon'] == 'Defender']['Fouls'])
x3 = list(df[df['Positon'] == 'Midfielder']['Fouls'])
x4 = list(df[df['Positon'] == 'Forward']['Fouls'])


# Assign colors for each airline and the names
colors = ['#E69F00', '#56B4E9', '#F0E442', '#009E73']
names = ['Goalkeeper', 'Defender', 'Midfielder',
         'Forward']
         
# Make the histogram using a list of lists
# Normalize the flights and assign colors and names
plt.hist([x1, x2, x3, x4], bins = int(180/15),
         color = colors, label=names)

# Plot formatting
plt.legend()
plt.xlabel('Position')
plt.ylabel(' Fouls')
plt.title('Side-by-Side Histogram with Positions')
plt.show()

# %%
sns.countplot(x="Fouls_ratio_dicretized", hue="Positon", data=df)
# Out:
# <AxesSubplot:xlabel='Fouls_ratio_dicretized', ylabel='count'>

# %%
x=df['Fouls_ratio'].values
k2, p = stats.normaltest(x)
alpha = 0.05
print("p = {:g}".format(p))

if p < alpha:  # null hypothesis: x comes from a normal distribution
    print("The null hypothesis can be rejected")
else:
    print("The null hypothesis cannot be rejected")
# Out:
# p = 0.610392
# The null hypothesis cannot be rejected

# %%
# creating empty contigency table

df_count=pd.DataFrame(columns=['Low Fouls Ration', 'Medium Fouls Ratio', 'High Fouls Ratio'], index=['Goal Keepers', 'Defenders',
                                                                                                    'MidFielders', 'Forwards'])
df_count
# Out:
#              Low Fouls Ration Medium Fouls Ratio High Fouls Ratio
# Goal Keepers              NaN                NaN              NaN
# Defenders                 NaN                NaN              NaN
# MidFielders               NaN                NaN              NaN
# Forwards                  NaN                NaN              NaN

# %%
# Filling the contingency table

df_count.iloc[0,0]=(df[  (df['Positon']=='Goalkeeper') &  (df['Fouls_ratio_dicretized']=='Low')])['Fouls_ratio_dicretized'].count()

df_count.iloc[0,1]=(df[  (df['Positon']=='Goalkeeper') &  (df['Fouls_ratio_dicretized']=='Medium')])['Fouls_ratio_dicretized'].count()

df_count.iloc[0,2]=(df[  (df['Positon']=='Goalkeeper') &  (df['Fouls_ratio_dicretized']=='High')])['Fouls_ratio_dicretized'].count()

df_count.iloc[1,0]=(df[  (df['Positon']=='Defender') &  (df['Fouls_ratio_dicretized']=='Low')])['Fouls_ratio_dicretized'].count()

df_count.iloc[1,1]=(df[  (df['Positon']=='Defender') &  (df['Fouls_ratio_dicretized']=='Medium')])['Fouls_ratio_dicretized'].count()

df_count.iloc[1,2]=(df[  (df['Positon']=='Defender') &  (df['Fouls_ratio_dicretized']=='High')])['Fouls_ratio_dicretized'].count()

df_count.iloc[2,0]=(df[  (df['Positon']=='Midfielder') &  (df['Fouls_ratio_dicretized']=='Low')])['Fouls_ratio_dicretized'].count()

df_count.iloc[2,1]=(df[  (df['Positon']=='Midfielder') &  (df['Fouls_ratio_dicretized']=='Medium')])['Fouls_ratio_dicretized'].count()

df_count.iloc[2,2]=(df[  (df['Positon']=='Midfielder') &  (df['Fouls_ratio_dicretized']=='High')])['Fouls_ratio_dicretized'].count()

df_count.iloc[3,0]=(df[  (df['Positon']=='Forward') &  (df['Fouls_ratio_dicretized']=='Low')])['Fouls_ratio_dicretized'].count()

df_count.iloc[3,1]=(df[  (df['Positon']=='Forward') &  (df['Fouls_ratio_dicretized']=='Medium')])['Fouls_ratio_dicretized'].count()

df_count.iloc[3,2]=(df[  (df['Positon']=='Forward') &  (df['Fouls_ratio_dicretized']=='High')])['Fouls_ratio_dicretized'].count()

# %%
df_count
# Out:
#              Low Fouls Ration Medium Fouls Ratio High Fouls Ratio
# Goal Keepers               51                  0                1
# Defenders                  33                 77               61
# MidFielders                50                 54               72
# Forwards                   36                 38               35

# %%
table=df_count.values

# %%
stat, p, dof, expected = chi2_contingency(table)
print('dof=%d' % dof)
print(expected)
print(p)
print(stat)
# interpret test-statistic
prob = 0.95
critical = chi2.ppf(prob, dof)
print('probability=%.3f, critical=%.3f, stat=%.3f' % (prob, critical, stat))
if abs(stat) >= critical:
	print('Dependent (reject H0)')
else:
	print('Independent (fail to reject H0)')
# interpret p-value
alpha = 1.0 - prob
print('significance=%.3f, p=%.3f' % (alpha, p))
if p <= alpha:
	print('Dependent (reject H0)')
else:
	print('Independent (fail to reject H0)')
# Out:
# dof=6
# [[17.4015748  17.2992126  17.2992126 ]
#  [57.22440945 56.88779528 56.88779528]
#  [58.8976378  58.5511811  58.5511811 ]
#  [36.47637795 36.26181102 36.26181102]]
# 1.5451446569512155e-23
# 120.11002241987822
# probability=0.950, critical=12.592, stat=120.110
# Dependent (reject H0)
# significance=0.050, p=0.000
# Dependent (reject H0)

# %%
df_count2=df_count.drop('Goal Keepers')
df_count2
# Out:
#             Low Fouls Ration Medium Fouls Ratio High Fouls Ratio
# Defenders                 33                 77               61
# MidFielders               50                 54               72
# Forwards                  36                 38               35

# %%
table=df_count2.values

# %%
stat, p, dof, expected = chi2_contingency(table)
print('dof=%d' % dof)
print(expected)
print(p)
print(stat)
# interpret test-statistic
prob = 0.95
critical = chi2.ppf(prob, dof)
print('probability=%.3f, critical=%.3f, stat=%.3f' % (prob, critical, stat))
if abs(stat) >= critical:
	print('Dependent (reject H0)')
else:
	print('Independent (fail to reject H0)')
# interpret p-value
alpha = 1.0 - prob
print('significance=%.3f, p=%.3f' % (alpha, p))
if p <= alpha:
	print('Dependent (reject H0)')
else:
	print('Independent (fail to reject H0)')
# Out:
# dof=4
# [[44.625      63.375      63.        ]
#  [45.92982456 65.22807018 64.84210526]
#  [28.44517544 40.39692982 40.15789474]]
# 0.017987765222033842
# 11.915896152684732
# probability=0.950, critical=9.488, stat=11.916
# Dependent (reject H0)
# significance=0.050, p=0.018
# Dependent (reject H0)

# %%
df_count3=df_count.drop(['Goal Keepers','Forwards'])
df_count3
# Out:
#             Low Fouls Ration Medium Fouls Ratio High Fouls Ratio
# Defenders                 33                 77               61
# MidFielders               50                 54               72

# %%
table=df_count3.values

# %%
stat, p, dof, expected = chi2_contingency(table)
print('dof=%d' % dof)
print(expected)
print(p)
print(stat)
# interpret test-statistic
prob = 0.95
critical = chi2.ppf(prob, dof)
print('probability=%.3f, critical=%.3f, stat=%.3f' % (prob, critical, stat))
if abs(stat) >= critical:
	print('Dependent (reject H0)')
else:
	print('Independent (fail to reject H0)')
# interpret p-value
alpha = 1.0 - prob
print('significance=%.3f, p=%.3f' % (alpha, p))
if p <= alpha:
	print('Dependent (reject H0)')
else:
	print('Independent (fail to reject H0)')
# Out:
# dof=2
# [[40.90201729 64.55619597 65.54178674]
#  [42.09798271 66.44380403 67.45821326]]
# 0.015301876396843965
# 8.359559635573714
# probability=0.950, critical=5.991, stat=8.360
# Dependent (reject H0)
# significance=0.050, p=0.015
# Dependent (reject H0)

# %%
df_count4=df_count.drop(['Goal Keepers','Defenders'])
df_count4
# Out:
#             Low Fouls Ration Medium Fouls Ratio High Fouls Ratio
# MidFielders               50                 54               72
# Forwards                  36                 38               35

# %%
table=df_count4.values

# %%
stat, p, dof, expected = chi2_contingency(table)
print('dof=%d' % dof)
print(expected)
print(p)
print(stat)
# interpret test-statistic
prob = 0.95
critical = chi2.ppf(prob, dof)
print('probability=%.3f, critical=%.3f, stat=%.3f' % (prob, critical, stat))
if abs(stat) >= critical:
	print('Dependent (reject H0)')
else:
	print('Independent (fail to reject H0)')
# interpret p-value
alpha = 1.0 - prob
print('significance=%.3f, p=%.3f' % (alpha, p))
if p <= alpha:
	print('Dependent (reject H0)')
else:
	print('Independent (fail to reject H0)')
# Out:
# dof=2
# [[53.10877193 56.81403509 66.07719298]
#  [32.89122807 35.18596491 40.92280702]]
# 0.3281865615641359
# 2.228346094077009
# probability=0.950, critical=5.991, stat=2.228
# Independent (fail to reject H0)
# significance=0.050, p=0.328
# Independent (fail to reject H0)

# %% [markdown]
# **Yellow cards**

# %%
sns.catplot(x="Positon", y="Yellowcardsd_ratio", kind="box", data=df)

# %%
#first plot relation between apps and fouls and apps and yellow cards

# %%
sns.relplot(x="Apps", y="Yellowcards", data=df)

# %%
sns.relplot(x="Apps", y="Yellowcards", hue='Positon' ,data=df)

# %%
#distribution of yellow cards ratio

# %%
# Make a separate list for each airline
x1 = list(df[df['Positon'] == 'Goalkeeper']['Yellowcards'])
x2 = list(df[df['Positon'] == 'Defender']['Yellowcards'])
x3 = list(df[df['Positon'] == 'Midfielder']['Yellowcards'])
x4 = list(df[df['Positon'] == 'Forward']['Yellowcards'])


# Assign colors for each airline and the names
colors = ['#E69F00', '#56B4E9', '#F0E442', '#009E73']
names = ['Goalkeeper', 'Defender', 'Midfielder',
         'Forward']
         
# Make the histogram using a list of lists
# Normalize the flights and assign colors and names
plt.hist([x1, x2, x3, x4], bins = int(180/15),
         color = colors, label=names)

# Plot formatting
plt.legend()
plt.xlabel('Position')
plt.ylabel(' Yellowcards')
plt.title('Side-by-Side Histogram with Positions')
plt.show()

# %%
# Make a separate list for each airline

x2 = list(df['Yellowcards'])



# Make the histogram using a list of lists
# Normalize the flights and assign colors and names
plt.hist( x2 ,bins = int(180/15))

# Plot formatting

plt.xlabel('Position')
plt.ylabel(' Yellowcards')
plt.title(' Histogram ')
plt.show()

# %%
sns.distplot(df['Yellowcards'], hist=True, kde=True, 
             bins=int(80/5), color = 'darkblue', 
             hist_kws={'edgecolor':'black'},
             kde_kws={'linewidth': 4})
# Out:
# C:\Users\Lenovo\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Yellowcards', ylabel='Density'>

# %%
# Make a separate list for each airline

x2 = list(df[df['Positon'] == 'Defender']['Yellowcards'])



# Make the histogram using a list of lists
# Normalize the flights and assign colors and names
plt.hist( x2 ,bins = int(180/15))

# Plot formatting

plt.xlabel('Position')
plt.ylabel(' Yellowcards')
plt.title(' Histogram ')
plt.show()

# %%
sns.distplot((df[df['Positon'] == 'Defender']['Yellowcards']), hist=True, kde=True, 
             bins=int(80/5), color = 'darkblue', 
             hist_kws={'edgecolor':'black'},
             kde_kws={'linewidth': 4})
# Out:
# C:\Users\Lenovo\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Yellowcards', ylabel='Density'>

# %%
# Make a separate list for each airline
x1 = list(df[df['Positon'] == 'Goalkeeper']['Fouls'])
x2 = list(df[df['Positon'] == 'Defender']['Fouls'])
x3 = list(df[df['Positon'] == 'Midfielder']['Fouls'])
x4 = list(df[df['Positon'] == 'Forward']['Fouls'])


# Assign colors for each airline and the names
colors = ['#E69F00', '#56B4E9', '#F0E442', '#009E73']
names = ['Goalkeeper', 'Defender', 'Midfielder',
         'Forward']
         
# Make the histogram using a list of lists
# Normalize the flights and assign colors and names
plt.hist([x1, x2, x3, x4], bins = int(180/15),
         color = colors, label=names)

# Plot formatting
plt.legend()
plt.xlabel('Position')
plt.ylabel('Fouls')
plt.title('Side-by-Side Histogram with Positions')
plt.show()

# %%
df[df['Apps']>100]['Fouls_ratio'].max()
# Out:
# 1.793103448275862

# %%
df[df['Yellowcardsd_ratio']==0.3333333333333333]
# Out:
#               Name              Team     Positon  Age  Apps  HeightCM  \
# 67   Morgan Sanson       Aston Villa  Midfielder   26     9     180.0
# 429  Fabian SchÃ¤r  Newcastle United    Defender   29    63     188.0
# 503    Caleb Watts   Southampton U21  Midfielder   19     3     175.0
#
#      WeightKG  Goals  Assists  Passes  Wins  Losses  Yellowcards  Redcards  \
# 67       73.0      0        0     138     2       4            3         0
# 429      84.0      6        1    2327    22      31           21         1
# 503       NaN      0        0      12     0       3            1         0
#
#      Fouls  Wins_ratio  Yellowcardsd_ratio  Fouls_ratio  Passes_ratio
# 67       6    0.222222            0.333333     0.666667     15.333333
# 429     79    0.349206            0.333333     1.253968     36.936508
# 503      0    0.000000            0.333333     0.000000      4.000000

# %%
#binomial distribution
fig, ax = plt.subplots(1, 1)

# %%
# descritize apps and plot the relation of each category in apps and other variables
#Descritize age and plot the relation between age and other variables
